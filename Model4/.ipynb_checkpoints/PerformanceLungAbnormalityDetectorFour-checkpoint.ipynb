# %%
# finding the best threasehold ::

import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt

# === Paths ===
model_path = r"C:\Users\Devansh\Desktop\Project Backups\Model4\LungAbnormalityDetectorFourModel_Xception.h5"
test_dir = r"C:\Users\Devansh\Desktop\Project Backups\LungAbnormalityDetectorDataset(PreprocessedAugmented)\Test"
IMG_SIZE = (256, 256)
BATCH_SIZE = 32
class_names = ["Normal", "Abnormal"]

# === Load Model ===
model = tf.keras.models.load_model(model_path, compile=False)

# === Load Dataset ===
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    label_mode='binary',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# === Get True Labels and Probabilities ===
y_true = []
y_probs = []

for images, labels in test_ds:
    probs = model.predict(images).flatten()
    y_probs.extend(probs)
    y_true.extend(labels.numpy())

y_true = np.array(y_true)
y_probs = np.array(y_probs)

# === Search Best Threshold ===
best_thresh = 0.5
best_f1 = 0.0
thresholds = np.arange(0.05, 0.95, 0.01)
f1_scores = []

for t in thresholds:
    preds = (y_probs > t).astype(int)
    f1 = f1_score(y_true, preds, pos_label=1)
    f1_scores.append(f1)
    if f1 > best_f1:
        best_f1 = f1
        best_thresh = t

# === Plot F1 vs Threshold ===
plt.plot(thresholds, f1_scores, marker='o')
plt.title("F1-Score vs Threshold (Abnormal class)")
plt.xlabel("Threshold")
plt.ylabel("F1-Score")
plt.grid(True)
plt.axvline(best_thresh, color='r', linestyle='--', label=f'Best: {best_thresh:.2f}')
plt.legend()
plt.tight_layout()
plt.show()

# === Print Best Threshold ===
print(f"\n✅ Best Threshold: {best_thresh:.2f}")
print(f"Maximum F1-Score for 'Abnormal' class: {best_f1:.4f}")
# Out:
# Found 780 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# ✅ Best Threshold: 0.48
# Maximum F1-Score for 'Abnormal' class: 0.8978

# %%
# model testing ::

import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# === USER SETTINGS ===
model_path = r"C:\Users\Devansh\Desktop\Project Backups\Model4\LungAbnormalityDetectorFourModel_Xception.h5"
test_dir = r"C:\Users\Devansh\Desktop\Project Backups\LungAbnormalityDetectorDataset(PreprocessedAugmented)\Test"

IMG_SIZE = (256, 256)
BATCH_SIZE = 32
threshold = 0.48  # Based on training
class_names = ["Abnormal", "Normal"]

# === Load Model ===
model = tf.keras.models.load_model(model_path, compile=False)

# === Load Dataset ===
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    label_mode='binary',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# === Predict & Evaluate ===
y_true, y_pred = [], []

# Get file paths in the same order as test_ds batches
all_file_paths = test_ds.file_paths  # tf >= 2.5
# If not available, use:
# all_file_paths = [f for subdir, _, files in os.walk(test_dir)
#                   for f in sorted(files)
#                   if f.lower().endswith(('.png','.jpg','.jpeg'))]

idx = 0
for batch_images, batch_labels in test_ds:
    probs = model.predict(batch_images).flatten()
    preds = (probs > threshold).astype(int)

    batch_size = len(batch_labels)
    for i in range(batch_size):
        img_path = all_file_paths[idx]
        bin_pred = preds[i]
        print(f"{os.path.basename(img_path):<30} → Predicted: {class_names[bin_pred]}")
        idx += 1

    y_true.extend(batch_labels.numpy().astype(int))
    y_pred.extend(preds)

# === Evaluation Metrics ===
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title(f"Confusion Matrix (Threshold = {threshold})")
plt.tight_layout()
plt.show()
# Out:
# Found 780 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Abnormal-1.png                 → Predicted: Normal
# Abnormal-10.png                → Predicted: Abnormal
# Abnormal-100.png               → Predicted: Abnormal
# Abnormal-101.png               → Predicted: Abnormal
# Abnormal-102.png               → Predicted: Abnormal
# Abnormal-103.png               → Predicted: Abnormal
# Abnormal-104.png               → Predicted: Abnormal
# Abnormal-105.png               → Predicted: Abnormal
# Abnormal-106.png               → Predicted: Normal
# Abnormal-107.png               → Predicted: Abnormal
# Abnormal-108.png               → Predicted: Abnormal
# Abnormal-109.png               → Predicted: Normal
# Abnormal-11.png                → Predicted: Normal
# Abnormal-110.png               → Predicted: Abnormal
# Abnormal-111.png               → Predicted: Abnormal
# Abnormal-112.png               → Predicted: Abnormal
# Abnormal-113.png               → Predicted: Abnormal
# Abnormal-114.png               → Predicted: Abnormal
# Abnormal-115.png               → Predicted: Normal
# Abnormal-116.png               → Predicted: Normal
# Abnormal-117.png               → Predicted: Abnormal
# Abnormal-118.png               → Predicted: Abnormal
# Abnormal-119.png               → Predicted: Normal
# Abnormal-12.png                → Predicted: Abnormal
# Abnormal-120.png               → Predicted: Abnormal
# Abnormal-121.png               → Predicted: Abnormal
# Abnormal-122.png               → Predicted: Abnormal
# Abnormal-123.png               → Predicted: Normal
# Abnormal-124.png               → Predicted: Abnormal
# Abnormal-125.png               → Predicted: Normal
# Abnormal-126.png               → Predicted: Abnormal
# Abnormal-127.png               → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-128.png               → Predicted: Abnormal
# Abnormal-129.png               → Predicted: Abnormal
# Abnormal-13.png                → Predicted: Abnormal
# Abnormal-130.png               → Predicted: Abnormal
# Abnormal-131.png               → Predicted: Normal
# Abnormal-132.png               → Predicted: Abnormal
# Abnormal-133.png               → Predicted: Abnormal
# Abnormal-134.png               → Predicted: Abnormal
# Abnormal-135.png               → Predicted: Normal
# Abnormal-136.png               → Predicted: Abnormal
# Abnormal-137.png               → Predicted: Abnormal
# Abnormal-138.png               → Predicted: Normal
# Abnormal-139.png               → Predicted: Abnormal
# Abnormal-14.png                → Predicted: Abnormal
# Abnormal-140.png               → Predicted: Abnormal
# Abnormal-141.png               → Predicted: Abnormal
# Abnormal-142.png               → Predicted: Normal
# Abnormal-143.png               → Predicted: Abnormal
# Abnormal-144.png               → Predicted: Normal
# Abnormal-145.png               → Predicted: Abnormal
# Abnormal-147.png               → Predicted: Abnormal
# Abnormal-15.png                → Predicted: Abnormal
# Abnormal-150.png               → Predicted: Abnormal
# Abnormal-151.png               → Predicted: Abnormal
# Abnormal-152.png               → Predicted: Abnormal
# Abnormal-153.png               → Predicted: Abnormal
# Abnormal-154.png               → Predicted: Abnormal
# Abnormal-155.png               → Predicted: Normal
# Abnormal-156.png               → Predicted: Abnormal
# Abnormal-157.png               → Predicted: Normal
# Abnormal-158.png               → Predicted: Abnormal
# Abnormal-159.png               → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-16.png                → Predicted: Abnormal
# Abnormal-160.png               → Predicted: Abnormal
# Abnormal-161.png               → Predicted: Abnormal
# Abnormal-162.png               → Predicted: Abnormal
# Abnormal-163.png               → Predicted: Abnormal
# Abnormal-164.png               → Predicted: Abnormal
# Abnormal-165.png               → Predicted: Abnormal
# Abnormal-167.png               → Predicted: Abnormal
# Abnormal-168.png               → Predicted: Abnormal
# Abnormal-169.png               → Predicted: Abnormal
# Abnormal-17.png                → Predicted: Abnormal
# Abnormal-170.png               → Predicted: Abnormal
# Abnormal-171.png               → Predicted: Normal
# Abnormal-172.png               → Predicted: Abnormal
# Abnormal-173.png               → Predicted: Abnormal
# Abnormal-174.png               → Predicted: Abnormal
# Abnormal-175.png               → Predicted: Normal
# Abnormal-176.png               → Predicted: Normal
# Abnormal-177.png               → Predicted: Abnormal
# Abnormal-178.png               → Predicted: Abnormal
# Abnormal-179.png               → Predicted: Normal
# Abnormal-18.png                → Predicted: Abnormal
# Abnormal-180.png               → Predicted: Abnormal
# Abnormal-181.png               → Predicted: Abnormal
# Abnormal-182.png               → Predicted: Abnormal
# Abnormal-183.png               → Predicted: Abnormal
# Abnormal-184.png               → Predicted: Abnormal
# Abnormal-185.png               → Predicted: Normal
# Abnormal-186.png               → Predicted: Abnormal
# Abnormal-187.png               → Predicted: Abnormal
# Abnormal-188.png               → Predicted: Abnormal
# Abnormal-189.png               → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-19.png                → Predicted: Abnormal
# Abnormal-190.png               → Predicted: Normal
# Abnormal-191.png               → Predicted: Normal
# Abnormal-192.png               → Predicted: Normal
# Abnormal-193.png               → Predicted: Abnormal
# Abnormal-194.png               → Predicted: Normal
# Abnormal-195.png               → Predicted: Abnormal
# Abnormal-196.png               → Predicted: Abnormal
# Abnormal-197.png               → Predicted: Abnormal
# Abnormal-198.png               → Predicted: Abnormal
# Abnormal-199.png               → Predicted: Abnormal
# Abnormal-2.png                 → Predicted: Abnormal
# Abnormal-20.png                → Predicted: Abnormal
# Abnormal-200.png               → Predicted: Abnormal
# Abnormal-202.png               → Predicted: Normal
# Abnormal-204.png               → Predicted: Normal
# Abnormal-207.png               → Predicted: Abnormal
# Abnormal-208.png               → Predicted: Abnormal
# Abnormal-21.png                → Predicted: Abnormal
# Abnormal-211.png               → Predicted: Abnormal
# Abnormal-212.png               → Predicted: Abnormal
# Abnormal-213.png               → Predicted: Abnormal
# Abnormal-214.png               → Predicted: Abnormal
# Abnormal-215.png               → Predicted: Abnormal
# Abnormal-217.png               → Predicted: Normal
# Abnormal-218.png               → Predicted: Abnormal
# Abnormal-219.png               → Predicted: Abnormal
# Abnormal-22.png                → Predicted: Abnormal
# Abnormal-220.png               → Predicted: Normal
# Abnormal-221.png               → Predicted: Abnormal
# Abnormal-222.png               → Predicted: Abnormal
# Abnormal-223.png               → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-224.png               → Predicted: Normal
# Abnormal-225.png               → Predicted: Abnormal
# Abnormal-226.png               → Predicted: Abnormal
# Abnormal-227.png               → Predicted: Abnormal
# Abnormal-228.png               → Predicted: Abnormal
# Abnormal-229.png               → Predicted: Abnormal
# Abnormal-23.png                → Predicted: Normal
# Abnormal-230.png               → Predicted: Abnormal
# Abnormal-232.png               → Predicted: Abnormal
# Abnormal-233.png               → Predicted: Abnormal
# Abnormal-235.png               → Predicted: Normal
# Abnormal-236.png               → Predicted: Abnormal
# Abnormal-237.png               → Predicted: Abnormal
# Abnormal-238.png               → Predicted: Abnormal
# Abnormal-239.png               → Predicted: Abnormal
# Abnormal-24.png                → Predicted: Abnormal
# Abnormal-240.png               → Predicted: Normal
# Abnormal-241.png               → Predicted: Abnormal
# Abnormal-242.png               → Predicted: Abnormal
# Abnormal-243.png               → Predicted: Abnormal
# Abnormal-244.png               → Predicted: Abnormal
# Abnormal-245.png               → Predicted: Abnormal
# Abnormal-246.png               → Predicted: Abnormal
# Abnormal-247.png               → Predicted: Abnormal
# Abnormal-248.png               → Predicted: Normal
# Abnormal-249.png               → Predicted: Abnormal
# Abnormal-25.png                → Predicted: Normal
# Abnormal-250.png               → Predicted: Abnormal
# Abnormal-251.png               → Predicted: Normal
# Abnormal-252.png               → Predicted: Abnormal
# Abnormal-253.png               → Predicted: Normal
# Abnormal-254.png               → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Abnormal-255.png               → Predicted: Abnormal
# Abnormal-256.png               → Predicted: Normal
# Abnormal-257.png               → Predicted: Abnormal
# Abnormal-258.png               → Predicted: Abnormal
# Abnormal-259.png               → Predicted: Normal
# Abnormal-26.png                → Predicted: Abnormal
# Abnormal-260.png               → Predicted: Abnormal
# Abnormal-261.png               → Predicted: Normal
# Abnormal-262.png               → Predicted: Abnormal
# Abnormal-264.png               → Predicted: Abnormal
# Abnormal-265.png               → Predicted: Normal
# Abnormal-266.png               → Predicted: Abnormal
# Abnormal-267.png               → Predicted: Abnormal
# Abnormal-268.png               → Predicted: Normal
# Abnormal-269.png               → Predicted: Abnormal
# Abnormal-27.png                → Predicted: Abnormal
# Abnormal-270.png               → Predicted: Abnormal
# Abnormal-271.png               → Predicted: Abnormal
# Abnormal-272.png               → Predicted: Normal
# Abnormal-273.png               → Predicted: Abnormal
# Abnormal-274.png               → Predicted: Abnormal
# Abnormal-275.png               → Predicted: Abnormal
# Abnormal-276.png               → Predicted: Abnormal
# Abnormal-277.png               → Predicted: Abnormal
# Abnormal-279.png               → Predicted: Abnormal
# Abnormal-28.png                → Predicted: Abnormal
# Abnormal-281.png               → Predicted: Abnormal
# Abnormal-283.png               → Predicted: Abnormal
# Abnormal-284.png               → Predicted: Abnormal
# Abnormal-285.png               → Predicted: Abnormal
# Abnormal-286.png               → Predicted: Abnormal
# Abnormal-287.png               → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-289.png               → Predicted: Abnormal
# Abnormal-29.png                → Predicted: Abnormal
# Abnormal-290.png               → Predicted: Abnormal
# Abnormal-291.png               → Predicted: Normal
# Abnormal-292.png               → Predicted: Abnormal
# Abnormal-293.png               → Predicted: Abnormal
# Abnormal-294.png               → Predicted: Abnormal
# Abnormal-295.png               → Predicted: Abnormal
# Abnormal-297.png               → Predicted: Abnormal
# Abnormal-298.png               → Predicted: Abnormal
# Abnormal-3.png                 → Predicted: Abnormal
# Abnormal-30.png                → Predicted: Abnormal
# Abnormal-300.png               → Predicted: Abnormal
# Abnormal-301.png               → Predicted: Abnormal
# Abnormal-302.png               → Predicted: Abnormal
# Abnormal-303.png               → Predicted: Normal
# Abnormal-304.png               → Predicted: Abnormal
# Abnormal-305.png               → Predicted: Abnormal
# Abnormal-306.png               → Predicted: Normal
# Abnormal-307.png               → Predicted: Abnormal
# Abnormal-308.png               → Predicted: Abnormal
# Abnormal-309.png               → Predicted: Abnormal
# Abnormal-31.png                → Predicted: Abnormal
# Abnormal-310.png               → Predicted: Abnormal
# Abnormal-311.png               → Predicted: Abnormal
# Abnormal-312.png               → Predicted: Abnormal
# Abnormal-313.png               → Predicted: Abnormal
# Abnormal-314.png               → Predicted: Abnormal
# Abnormal-315.png               → Predicted: Abnormal
# Abnormal-316.png               → Predicted: Normal
# Abnormal-317.png               → Predicted: Abnormal
# Abnormal-318.png               → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Abnormal-319.png               → Predicted: Abnormal
# Abnormal-32.png                → Predicted: Normal
# Abnormal-320.png               → Predicted: Abnormal
# Abnormal-321.png               → Predicted: Abnormal
# Abnormal-322.png               → Predicted: Abnormal
# Abnormal-323.png               → Predicted: Abnormal
# Abnormal-324.png               → Predicted: Abnormal
# Abnormal-325.png               → Predicted: Abnormal
# Abnormal-326.png               → Predicted: Abnormal
# Abnormal-327.png               → Predicted: Abnormal
# Abnormal-328.png               → Predicted: Abnormal
# Abnormal-329.png               → Predicted: Abnormal
# Abnormal-33.png                → Predicted: Normal
# Abnormal-330.png               → Predicted: Abnormal
# Abnormal-331.png               → Predicted: Abnormal
# Abnormal-332.png               → Predicted: Abnormal
# Abnormal-333.png               → Predicted: Abnormal
# Abnormal-334.png               → Predicted: Abnormal
# Abnormal-335.png               → Predicted: Abnormal
# Abnormal-336.png               → Predicted: Abnormal
# Abnormal-337.png               → Predicted: Abnormal
# Abnormal-338.png               → Predicted: Abnormal
# Abnormal-339.png               → Predicted: Normal
# Abnormal-34.png                → Predicted: Abnormal
# Abnormal-340.png               → Predicted: Abnormal
# Abnormal-341.png               → Predicted: Abnormal
# Abnormal-342.png               → Predicted: Abnormal
# Abnormal-343.png               → Predicted: Abnormal
# Abnormal-344.png               → Predicted: Abnormal
# Abnormal-345.png               → Predicted: Abnormal
# Abnormal-346.png               → Predicted: Abnormal
# Abnormal-347.png               → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-348.png               → Predicted: Abnormal
# Abnormal-349.png               → Predicted: Abnormal
# Abnormal-35.png                → Predicted: Abnormal
# Abnormal-350.png               → Predicted: Abnormal
# Abnormal-351.png               → Predicted: Abnormal
# Abnormal-352.png               → Predicted: Abnormal
# Abnormal-353.png               → Predicted: Abnormal
# Abnormal-354.png               → Predicted: Abnormal
# Abnormal-355.png               → Predicted: Normal
# Abnormal-356.png               → Predicted: Abnormal
# Abnormal-357.png               → Predicted: Abnormal
# Abnormal-358.png               → Predicted: Abnormal
# Abnormal-359.png               → Predicted: Abnormal
# Abnormal-36.png                → Predicted: Abnormal
# Abnormal-360.png               → Predicted: Abnormal
# Abnormal-361.png               → Predicted: Abnormal
# Abnormal-362.png               → Predicted: Abnormal
# Abnormal-363.png               → Predicted: Abnormal
# Abnormal-364.png               → Predicted: Abnormal
# Abnormal-365.png               → Predicted: Abnormal
# Abnormal-366.png               → Predicted: Abnormal
# Abnormal-367.png               → Predicted: Abnormal
# Abnormal-368.png               → Predicted: Abnormal
# Abnormal-369.png               → Predicted: Abnormal
# Abnormal-37.png                → Predicted: Abnormal
# Abnormal-370.png               → Predicted: Abnormal
# Abnormal-371.png               → Predicted: Abnormal
# Abnormal-372.png               → Predicted: Abnormal
# Abnormal-373.png               → Predicted: Normal
# Abnormal-374.png               → Predicted: Abnormal
# Abnormal-375.png               → Predicted: Abnormal
# Abnormal-376.png               → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-377.png               → Predicted: Abnormal
# Abnormal-378.png               → Predicted: Abnormal
# Abnormal-379.png               → Predicted: Abnormal
# Abnormal-38.png                → Predicted: Abnormal
# Abnormal-380.png               → Predicted: Normal
# Abnormal-381.png               → Predicted: Abnormal
# Abnormal-382.png               → Predicted: Abnormal
# Abnormal-383.png               → Predicted: Normal
# Abnormal-384.png               → Predicted: Abnormal
# Abnormal-385.png               → Predicted: Abnormal
# Abnormal-386.png               → Predicted: Abnormal
# Abnormal-387.png               → Predicted: Abnormal
# Abnormal-388.png               → Predicted: Abnormal
# Abnormal-389.png               → Predicted: Abnormal
# Abnormal-39.png                → Predicted: Abnormal
# Abnormal-390.png               → Predicted: Abnormal
# Abnormal-391.png               → Predicted: Abnormal
# Abnormal-392.png               → Predicted: Abnormal
# Abnormal-393.png               → Predicted: Abnormal
# Abnormal-394.png               → Predicted: Normal
# Abnormal-395.png               → Predicted: Abnormal
# Abnormal-396.png               → Predicted: Abnormal
# Abnormal-397.png               → Predicted: Normal
# Abnormal-398.png               → Predicted: Normal
# Abnormal-399.png               → Predicted: Abnormal
# Abnormal-4.png                 → Predicted: Abnormal
# Abnormal-40.png                → Predicted: Abnormal
# Abnormal-400.png               → Predicted: Normal
# Abnormal-41.png                → Predicted: Abnormal
# Abnormal-42.png                → Predicted: Abnormal
# Abnormal-43.png                → Predicted: Abnormal
# Abnormal-44.png                → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Abnormal-45.png                → Predicted: Normal
# Abnormal-46.png                → Predicted: Abnormal
# Abnormal-47.png                → Predicted: Abnormal
# Abnormal-48.png                → Predicted: Abnormal
# Abnormal-49.png                → Predicted: Abnormal
# Abnormal-5.png                 → Predicted: Abnormal
# Abnormal-50.png                → Predicted: Normal
# Abnormal-51.png                → Predicted: Abnormal
# Abnormal-52.png                → Predicted: Abnormal
# Abnormal-53.png                → Predicted: Abnormal
# Abnormal-54.png                → Predicted: Normal
# Abnormal-55.png                → Predicted: Abnormal
# Abnormal-56.png                → Predicted: Abnormal
# Abnormal-57.png                → Predicted: Abnormal
# Abnormal-58.png                → Predicted: Abnormal
# Abnormal-59.png                → Predicted: Abnormal
# Abnormal-6.png                 → Predicted: Abnormal
# Abnormal-60.png                → Predicted: Abnormal
# Abnormal-61.png                → Predicted: Abnormal
# Abnormal-62.png                → Predicted: Abnormal
# Abnormal-63.png                → Predicted: Normal
# Abnormal-64.png                → Predicted: Abnormal
# Abnormal-65.png                → Predicted: Abnormal
# Abnormal-66.png                → Predicted: Abnormal
# Abnormal-67.png                → Predicted: Abnormal
# Abnormal-68.png                → Predicted: Abnormal
# Abnormal-69.png                → Predicted: Abnormal
# Abnormal-7.png                 → Predicted: Abnormal
# Abnormal-70.png                → Predicted: Abnormal
# Abnormal-71.png                → Predicted: Abnormal
# Abnormal-72.png                → Predicted: Abnormal
# Abnormal-73.png                → Predicted: Abnormal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Abnormal-74.png                → Predicted: Normal
# Abnormal-75.png                → Predicted: Abnormal
# Abnormal-76.png                → Predicted: Abnormal
# Abnormal-77.png                → Predicted: Abnormal
# Abnormal-78.png                → Predicted: Abnormal
# Abnormal-79.png                → Predicted: Abnormal
# Abnormal-8.png                 → Predicted: Abnormal
# Abnormal-80.png                → Predicted: Abnormal
# Abnormal-81.png                → Predicted: Normal
# Abnormal-82.png                → Predicted: Abnormal
# Abnormal-83.png                → Predicted: Abnormal
# Abnormal-84.png                → Predicted: Abnormal
# Abnormal-85.png                → Predicted: Abnormal
# Abnormal-86.png                → Predicted: Normal
# Abnormal-87.png                → Predicted: Normal
# Abnormal-88.png                → Predicted: Abnormal
# Abnormal-89.png                → Predicted: Abnormal
# Abnormal-9.png                 → Predicted: Abnormal
# Abnormal-90.png                → Predicted: Abnormal
# Abnormal-91.png                → Predicted: Abnormal
# Abnormal-92.png                → Predicted: Abnormal
# Abnormal-93.png                → Predicted: Abnormal
# Abnormal-94.png                → Predicted: Abnormal
# Abnormal-95.png                → Predicted: Abnormal
# Abnormal-96.png                → Predicted: Abnormal
# Abnormal-97.png                → Predicted: Abnormal
# Abnormal-98.png                → Predicted: Abnormal
# Abnormal-99.png                → Predicted: Abnormal
# Normal-1.png                   → Predicted: Normal
# Normal-10.png                  → Predicted: Normal
# Normal-100.png                 → Predicted: Abnormal
# Normal-101.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-102.png                 → Predicted: Normal
# Normal-103.png                 → Predicted: Normal
# Normal-104.png                 → Predicted: Normal
# Normal-105.png                 → Predicted: Normal
# Normal-106.png                 → Predicted: Normal
# Normal-107.png                 → Predicted: Normal
# Normal-108.png                 → Predicted: Normal
# Normal-109.png                 → Predicted: Normal
# Normal-11.png                  → Predicted: Normal
# Normal-110.png                 → Predicted: Normal
# Normal-111.png                 → Predicted: Normal
# Normal-112.png                 → Predicted: Normal
# Normal-113.png                 → Predicted: Normal
# Normal-114.png                 → Predicted: Normal
# Normal-115.png                 → Predicted: Normal
# Normal-116.png                 → Predicted: Normal
# Normal-117.png                 → Predicted: Normal
# Normal-118.png                 → Predicted: Normal
# Normal-119.png                 → Predicted: Normal
# Normal-12.png                  → Predicted: Abnormal
# Normal-120.png                 → Predicted: Normal
# Normal-121.png                 → Predicted: Normal
# Normal-122.png                 → Predicted: Abnormal
# Normal-123.png                 → Predicted: Normal
# Normal-124.png                 → Predicted: Normal
# Normal-125.png                 → Predicted: Abnormal
# Normal-126.png                 → Predicted: Normal
# Normal-127.png                 → Predicted: Normal
# Normal-128.png                 → Predicted: Normal
# Normal-129.png                 → Predicted: Normal
# Normal-13.png                  → Predicted: Normal
# Normal-130.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-131.png                 → Predicted: Normal
# Normal-132.png                 → Predicted: Normal
# Normal-133.png                 → Predicted: Normal
# Normal-134.png                 → Predicted: Normal
# Normal-135.png                 → Predicted: Normal
# Normal-136.png                 → Predicted: Normal
# Normal-137.png                 → Predicted: Normal
# Normal-138.png                 → Predicted: Normal
# Normal-139.png                 → Predicted: Normal
# Normal-14.png                  → Predicted: Normal
# Normal-140.png                 → Predicted: Normal
# Normal-141.png                 → Predicted: Abnormal
# Normal-142.png                 → Predicted: Normal
# Normal-143.png                 → Predicted: Normal
# Normal-144.png                 → Predicted: Normal
# Normal-145.png                 → Predicted: Normal
# Normal-146.png                 → Predicted: Normal
# Normal-147.png                 → Predicted: Normal
# Normal-148.png                 → Predicted: Normal
# Normal-149.png                 → Predicted: Normal
# Normal-15.png                  → Predicted: Normal
# Normal-150.png                 → Predicted: Normal
# Normal-151.png                 → Predicted: Normal
# Normal-152.png                 → Predicted: Normal
# Normal-153.png                 → Predicted: Normal
# Normal-154.png                 → Predicted: Normal
# Normal-155.png                 → Predicted: Normal
# Normal-156.png                 → Predicted: Normal
# Normal-157.png                 → Predicted: Normal
# Normal-158.png                 → Predicted: Normal
# Normal-159.png                 → Predicted: Normal
# Normal-16.png                  → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Normal-160.png                 → Predicted: Normal
# Normal-161.png                 → Predicted: Normal
# Normal-162.png                 → Predicted: Normal
# Normal-163.png                 → Predicted: Normal
# Normal-164.png                 → Predicted: Normal
# Normal-165.png                 → Predicted: Normal
# Normal-166.png                 → Predicted: Normal
# Normal-167.png                 → Predicted: Normal
# Normal-168.png                 → Predicted: Normal
# Normal-169.png                 → Predicted: Normal
# Normal-17.png                  → Predicted: Normal
# Normal-170.png                 → Predicted: Normal
# Normal-171.png                 → Predicted: Abnormal
# Normal-172.png                 → Predicted: Normal
# Normal-173.png                 → Predicted: Normal
# Normal-174.png                 → Predicted: Normal
# Normal-175.png                 → Predicted: Normal
# Normal-176.png                 → Predicted: Normal
# Normal-177.png                 → Predicted: Normal
# Normal-178.png                 → Predicted: Normal
# Normal-179.png                 → Predicted: Normal
# Normal-18.png                  → Predicted: Normal
# Normal-180.png                 → Predicted: Normal
# Normal-181.png                 → Predicted: Normal
# Normal-182.png                 → Predicted: Normal
# Normal-183.png                 → Predicted: Normal
# Normal-184.png                 → Predicted: Normal
# Normal-185.png                 → Predicted: Normal
# Normal-186.png                 → Predicted: Normal
# Normal-187.png                 → Predicted: Normal
# Normal-188.png                 → Predicted: Normal
# Normal-189.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-19.png                  → Predicted: Normal
# Normal-190.png                 → Predicted: Normal
# Normal-191.png                 → Predicted: Normal
# Normal-192.png                 → Predicted: Normal
# Normal-193.png                 → Predicted: Normal
# Normal-194.png                 → Predicted: Normal
# Normal-195.png                 → Predicted: Normal
# Normal-196.png                 → Predicted: Normal
# Normal-197.png                 → Predicted: Normal
# Normal-198.png                 → Predicted: Normal
# Normal-199.png                 → Predicted: Normal
# Normal-2.png                   → Predicted: Normal
# Normal-20.png                  → Predicted: Normal
# Normal-200.png                 → Predicted: Normal
# Normal-201.png                 → Predicted: Normal
# Normal-202.png                 → Predicted: Normal
# Normal-203.png                 → Predicted: Normal
# Normal-204.png                 → Predicted: Normal
# Normal-205.png                 → Predicted: Normal
# Normal-206.png                 → Predicted: Normal
# Normal-207.png                 → Predicted: Normal
# Normal-208.png                 → Predicted: Normal
# Normal-209.png                 → Predicted: Normal
# Normal-21.png                  → Predicted: Normal
# Normal-210.png                 → Predicted: Normal
# Normal-211.png                 → Predicted: Normal
# Normal-212.png                 → Predicted: Normal
# Normal-213.png                 → Predicted: Normal
# Normal-214.png                 → Predicted: Normal
# Normal-215.png                 → Predicted: Normal
# Normal-216.png                 → Predicted: Normal
# Normal-217.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-218.png                 → Predicted: Normal
# Normal-219.png                 → Predicted: Normal
# Normal-22.png                  → Predicted: Normal
# Normal-220.png                 → Predicted: Normal
# Normal-221.png                 → Predicted: Normal
# Normal-222.png                 → Predicted: Normal
# Normal-223.png                 → Predicted: Normal
# Normal-224.png                 → Predicted: Normal
# Normal-225.png                 → Predicted: Abnormal
# Normal-226.png                 → Predicted: Normal
# Normal-227.png                 → Predicted: Abnormal
# Normal-228.png                 → Predicted: Normal
# Normal-229.png                 → Predicted: Normal
# Normal-23.png                  → Predicted: Normal
# Normal-230.png                 → Predicted: Normal
# Normal-231.png                 → Predicted: Normal
# Normal-232.png                 → Predicted: Normal
# Normal-233.png                 → Predicted: Normal
# Normal-234.png                 → Predicted: Normal
# Normal-235.png                 → Predicted: Normal
# Normal-236.png                 → Predicted: Normal
# Normal-237.png                 → Predicted: Normal
# Normal-238.png                 → Predicted: Normal
# Normal-239.png                 → Predicted: Normal
# Normal-24.png                  → Predicted: Normal
# Normal-240.png                 → Predicted: Normal
# Normal-241.png                 → Predicted: Normal
# Normal-242.png                 → Predicted: Normal
# Normal-243.png                 → Predicted: Normal
# Normal-244.png                 → Predicted: Normal
# Normal-245.png                 → Predicted: Normal
# Normal-246.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-247.png                 → Predicted: Normal
# Normal-248.png                 → Predicted: Normal
# Normal-249.png                 → Predicted: Normal
# Normal-25.png                  → Predicted: Normal
# Normal-250.png                 → Predicted: Normal
# Normal-251.png                 → Predicted: Normal
# Normal-252.png                 → Predicted: Normal
# Normal-253.png                 → Predicted: Normal
# Normal-254.png                 → Predicted: Normal
# Normal-255.png                 → Predicted: Normal
# Normal-256.png                 → Predicted: Normal
# Normal-257.png                 → Predicted: Normal
# Normal-258.png                 → Predicted: Normal
# Normal-259.png                 → Predicted: Normal
# Normal-26.png                  → Predicted: Normal
# Normal-260.png                 → Predicted: Normal
# Normal-261.png                 → Predicted: Normal
# Normal-262.png                 → Predicted: Normal
# Normal-263.png                 → Predicted: Normal
# Normal-264.png                 → Predicted: Normal
# Normal-265.png                 → Predicted: Normal
# Normal-266.png                 → Predicted: Normal
# Normal-267.png                 → Predicted: Normal
# Normal-268.png                 → Predicted: Normal
# Normal-269.png                 → Predicted: Normal
# Normal-27.png                  → Predicted: Normal
# Normal-270.png                 → Predicted: Normal
# Normal-271.png                 → Predicted: Normal
# Normal-272.png                 → Predicted: Normal
# Normal-273.png                 → Predicted: Normal
# Normal-274.png                 → Predicted: Normal
# Normal-275.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-276.png                 → Predicted: Normal
# Normal-277.png                 → Predicted: Normal
# Normal-278.png                 → Predicted: Normal
# Normal-279.png                 → Predicted: Normal
# Normal-28.png                  → Predicted: Normal
# Normal-280.png                 → Predicted: Normal
# Normal-281.png                 → Predicted: Normal
# Normal-282.png                 → Predicted: Normal
# Normal-283.png                 → Predicted: Normal
# Normal-284.png                 → Predicted: Normal
# Normal-285.png                 → Predicted: Normal
# Normal-286.png                 → Predicted: Normal
# Normal-287.png                 → Predicted: Normal
# Normal-288.png                 → Predicted: Normal
# Normal-289.png                 → Predicted: Normal
# Normal-29.png                  → Predicted: Normal
# Normal-290.png                 → Predicted: Normal
# Normal-291.png                 → Predicted: Normal
# Normal-292.png                 → Predicted: Normal
# Normal-293.png                 → Predicted: Normal
# Normal-294.png                 → Predicted: Normal
# Normal-295.png                 → Predicted: Normal
# Normal-296.png                 → Predicted: Normal
# Normal-297.png                 → Predicted: Normal
# Normal-298.png                 → Predicted: Normal
# Normal-299.png                 → Predicted: Normal
# Normal-3.png                   → Predicted: Normal
# Normal-30.png                  → Predicted: Normal
# Normal-300.png                 → Predicted: Normal
# Normal-301.png                 → Predicted: Normal
# Normal-302.png                 → Predicted: Normal
# Normal-303.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-304.png                 → Predicted: Normal
# Normal-305.png                 → Predicted: Normal
# Normal-306.png                 → Predicted: Abnormal
# Normal-307.png                 → Predicted: Normal
# Normal-308.png                 → Predicted: Normal
# Normal-309.png                 → Predicted: Normal
# Normal-31.png                  → Predicted: Normal
# Normal-310.png                 → Predicted: Abnormal
# Normal-311.png                 → Predicted: Normal
# Normal-312.png                 → Predicted: Normal
# Normal-313.png                 → Predicted: Normal
# Normal-314.png                 → Predicted: Normal
# Normal-315.png                 → Predicted: Normal
# Normal-316.png                 → Predicted: Normal
# Normal-317.png                 → Predicted: Normal
# Normal-318.png                 → Predicted: Normal
# Normal-319.png                 → Predicted: Normal
# Normal-32.png                  → Predicted: Normal
# Normal-320.png                 → Predicted: Normal
# Normal-321.png                 → Predicted: Normal
# Normal-322.png                 → Predicted: Normal
# Normal-323.png                 → Predicted: Normal
# Normal-324.png                 → Predicted: Normal
# Normal-325.png                 → Predicted: Abnormal
# Normal-326.png                 → Predicted: Normal
# Normal-327.png                 → Predicted: Normal
# Normal-328.png                 → Predicted: Normal
# Normal-329.png                 → Predicted: Normal
# Normal-33.png                  → Predicted: Normal
# Normal-330.png                 → Predicted: Abnormal
# Normal-331.png                 → Predicted: Normal
# Normal-332.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Normal-333.png                 → Predicted: Normal
# Normal-334.png                 → Predicted: Normal
# Normal-335.png                 → Predicted: Normal
# Normal-336.png                 → Predicted: Normal
# Normal-337.png                 → Predicted: Normal
# Normal-338.png                 → Predicted: Normal
# Normal-339.png                 → Predicted: Normal
# Normal-34.png                  → Predicted: Normal
# Normal-340.png                 → Predicted: Normal
# Normal-341.png                 → Predicted: Normal
# Normal-342.png                 → Predicted: Normal
# Normal-343.png                 → Predicted: Normal
# Normal-344.png                 → Predicted: Normal
# Normal-345.png                 → Predicted: Normal
# Normal-346.png                 → Predicted: Normal
# Normal-347.png                 → Predicted: Normal
# Normal-348.png                 → Predicted: Normal
# Normal-349.png                 → Predicted: Normal
# Normal-35.png                  → Predicted: Normal
# Normal-350.png                 → Predicted: Normal
# Normal-351.png                 → Predicted: Normal
# Normal-352.png                 → Predicted: Normal
# Normal-353.png                 → Predicted: Normal
# Normal-354.png                 → Predicted: Normal
# Normal-355.png                 → Predicted: Normal
# Normal-356.png                 → Predicted: Normal
# Normal-357.png                 → Predicted: Normal
# Normal-358.png                 → Predicted: Normal
# Normal-359.png                 → Predicted: Normal
# Normal-36.png                  → Predicted: Normal
# Normal-360.png                 → Predicted: Normal
# Normal-361.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Normal-362.png                 → Predicted: Normal
# Normal-363.png                 → Predicted: Normal
# Normal-364.png                 → Predicted: Normal
# Normal-365.png                 → Predicted: Normal
# Normal-366.png                 → Predicted: Normal
# Normal-367.png                 → Predicted: Normal
# Normal-368.png                 → Predicted: Normal
# Normal-369.png                 → Predicted: Normal
# Normal-37.png                  → Predicted: Normal
# Normal-370.png                 → Predicted: Normal
# Normal-371.png                 → Predicted: Normal
# Normal-372.png                 → Predicted: Normal
# Normal-373.png                 → Predicted: Normal
# Normal-374.png                 → Predicted: Abnormal
# Normal-375.png                 → Predicted: Normal
# Normal-376.png                 → Predicted: Normal
# Normal-377.png                 → Predicted: Abnormal
# Normal-378.png                 → Predicted: Normal
# Normal-379.png                 → Predicted: Normal
# Normal-38.png                  → Predicted: Normal
# Normal-380.png                 → Predicted: Normal
# Normal-381.png                 → Predicted: Normal
# Normal-382.png                 → Predicted: Normal
# Normal-383.png                 → Predicted: Normal
# Normal-384.png                 → Predicted: Normal
# Normal-385.png                 → Predicted: Normal
# Normal-386.png                 → Predicted: Abnormal
# Normal-387.png                 → Predicted: Normal
# Normal-388.png                 → Predicted: Normal
# Normal-389.png                 → Predicted: Normal
# Normal-39.png                  → Predicted: Normal
# Normal-390.png                 → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Normal-391.png                 → Predicted: Normal
# Normal-392.png                 → Predicted: Normal
# Normal-393.png                 → Predicted: Normal
# Normal-394.png                 → Predicted: Normal
# Normal-395.png                 → Predicted: Normal
# Normal-396.png                 → Predicted: Normal
# Normal-397.png                 → Predicted: Normal
# Normal-398.png                 → Predicted: Normal
# Normal-399.png                 → Predicted: Normal
# Normal-4.png                   → Predicted: Normal
# Normal-40.png                  → Predicted: Abnormal
# Normal-400.png                 → Predicted: Normal
# Normal-41.png                  → Predicted: Normal
# Normal-42.png                  → Predicted: Normal
# Normal-43.png                  → Predicted: Normal
# Normal-44.png                  → Predicted: Normal
# Normal-45.png                  → Predicted: Normal
# Normal-46.png                  → Predicted: Normal
# Normal-47.png                  → Predicted: Normal
# Normal-48.png                  → Predicted: Normal
# Normal-49.png                  → Predicted: Normal
# Normal-5.png                   → Predicted: Normal
# Normal-50.png                  → Predicted: Normal
# Normal-51.png                  → Predicted: Normal
# Normal-52.png                  → Predicted: Normal
# Normal-53.png                  → Predicted: Normal
# Normal-54.png                  → Predicted: Normal
# Normal-55.png                  → Predicted: Normal
# Normal-56.png                  → Predicted: Normal
# Normal-57.png                  → Predicted: Normal
# Normal-58.png                  → Predicted: Normal
# Normal-59.png                  → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Normal-6.png                   → Predicted: Normal
# Normal-60.png                  → Predicted: Normal
# Normal-61.png                  → Predicted: Normal
# Normal-62.png                  → Predicted: Normal
# Normal-63.png                  → Predicted: Normal
# Normal-64.png                  → Predicted: Normal
# Normal-65.png                  → Predicted: Normal
# Normal-66.png                  → Predicted: Normal
# Normal-67.png                  → Predicted: Normal
# Normal-68.png                  → Predicted: Normal
# Normal-69.png                  → Predicted: Normal
# Normal-7.png                   → Predicted: Normal
# Normal-70.png                  → Predicted: Abnormal
# Normal-71.png                  → Predicted: Normal
# Normal-72.png                  → Predicted: Normal
# Normal-73.png                  → Predicted: Normal
# Normal-74.png                  → Predicted: Normal
# Normal-75.png                  → Predicted: Normal
# Normal-76.png                  → Predicted: Normal
# Normal-77.png                  → Predicted: Normal
# Normal-78.png                  → Predicted: Normal
# Normal-79.png                  → Predicted: Normal
# Normal-8.png                   → Predicted: Normal
# Normal-80.png                  → Predicted: Abnormal
# Normal-81.png                  → Predicted: Normal
# Normal-82.png                  → Predicted: Normal
# Normal-83.png                  → Predicted: Normal
# Normal-84.png                  → Predicted: Normal
# Normal-85.png                  → Predicted: Normal
# Normal-86.png                  → Predicted: Normal
# Normal-87.png                  → Predicted: Normal
# Normal-88.png                  → Predicted: Normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Normal-89.png                  → Predicted: Normal
# Normal-9.png                   → Predicted: Normal
# Normal-90.png                  → Predicted: Normal
# Normal-91.png                  → Predicted: Normal
# Normal-92.png                  → Predicted: Normal
# Normal-93.png                  → Predicted: Normal
# Normal-94.png                  → Predicted: Normal
# Normal-95.png                  → Predicted: Normal
# Normal-96.png                  → Predicted: Normal
# Normal-97.png                  → Predicted: Normal
# Normal-98.png                  → Predicted: Normal
# Normal-99.png                  → Predicted: Normal
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#     Abnormal       0.95      0.82      0.88       380
#       Normal       0.85      0.95      0.90       400
#
#     accuracy                           0.89       780
#    macro avg       0.90      0.89      0.89       780
# weighted avg       0.89      0.89      0.89       780
