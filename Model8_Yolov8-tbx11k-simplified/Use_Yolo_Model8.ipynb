# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO(r"C:\Users\Devansh\Desktop\ProjectYolo\Model8_Yolov8-tbx11k-simplified\best_tb_model.pt")

# %%
# best threshold is 

# Predict on an image
results = model.predict(r"C:\Users\Devansh\Desktop\ProjectYolo\yolo-Datasets\yolo-tbx11k-simplified\images\val\tb0832.png", conf=0.05)

# Show results
results[0].show()
# Out:
# image 1/1 C:\Users\Devansh\Desktop\ProjectYolo\yolo-Datasets\yolo-tbx11k-simplified\images\val\tb0832.png: 512x512 3 tbs, 623.3ms
# Speed: 10.7ms preprocess, 623.3ms inference, 28.5ms postprocess per image at shape (1, 3, 512, 512)
