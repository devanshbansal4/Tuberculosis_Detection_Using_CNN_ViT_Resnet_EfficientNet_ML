# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB3
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2025-06-19 14:49:14.480612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750344554.724947      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750344554.792653      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# ⚠️ Focal Loss Function
def focal_loss(gamma=2.0, alpha=0.75):
    def loss(y_true, y_pred):
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
        return -tf.reduce_mean(alpha * tf.pow(1. - pt, gamma) * tf.math.log(pt))
    return loss

# ⚙️ Paths
BASE_DIR = "/kaggle/input/lungabnormalitydetectordataset/LungAbnormalityDetectorDataset(PreprocessedAugmented)"
train_dir = os.path.join(BASE_DIR, "Train")
val_dir = os.path.join(BASE_DIR, "Validation")
test_dir = os.path.join(BASE_DIR, "Test")

# 📦 Load Datasets
IMG_SIZE = (256, 256)
BATCH_SIZE = 32

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, label_mode='binary', image_size=IMG_SIZE, batch_size=BATCH_SIZE
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, label_mode='binary', image_size=IMG_SIZE, batch_size=BATCH_SIZE
)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir, label_mode='binary', image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False
)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)

# ⚖️ Manually bias: prioritize recall for abnormal (class 1)
class_weights = {0: 0.5, 1: 2.0}  # You can tune further

# 🔁 Data Augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# 🧠 Model Architecture
base_model = EfficientNetB3(include_top=False, weights='imagenet', input_shape=(256, 256, 3))
base_model.trainable = False  # Freeze initially

model = models.Sequential([
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# Found 8910 files belonging to 2 classes.
# I0000 00:00:1750344599.247646      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1750344599.248322      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 790 files belonging to 2 classes.
# Found 780 files belonging to 2 classes.
# ...
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# ⚙️ Compile with focal loss
model.compile(
    optimizer='adam',
    loss=focal_loss(gamma=2.0, alpha=0.75),
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# ⏱️ Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint("model1_normal_vs_abnormal.h5", save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)
]

# 🚀 Initial Training
history = model.fit(train_ds, validation_data=val_ds, epochs=10,
                    class_weight=class_weights, callbacks=callbacks)
# Out:
# Epoch 1/10
# E0000 00:00:1750344657.169125      35 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1_1/efficientnetb3_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1750344660.472952      88 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 88s 213ms/step - accuracy: 0.8085 - auc: 0.8853 - loss: 0.1071 - val_accuracy: 0.8241 - val_auc: 0.9156 - val_loss: 0.0867 - learning_rate: 0.0010
# Epoch 2/10
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 55s 198ms/step - accuracy: 0.8984 - auc: 0.9641 - loss: 0.0610 - val_accuracy: 0.8215 - val_auc: 0.9408 - val_loss: 0.0803 - learning_rate: 0.0010
# Epoch 3/10
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 57s 204ms/step - accuracy: 0.9092 - auc: 0.9718 - loss: 0.0538 - val_accuracy: 0.7291 - val_auc: 0.9569 - val_loss: 0.0997 - learning_rate: 0.0010
# Epoch 4/10
# ...

# %%
# 🔓 Fine-tuning
base_model.trainable = True
for layer in base_model.layers[:100]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss=focal_loss(gamma=2.0, alpha=0.75),
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

fine_tune_history = model.fit(train_ds, validation_data=val_ds, epochs=10,
                              class_weight=class_weights, callbacks=callbacks)
# Out:
# Epoch 1/10
# E0000 00:00:1750345306.264904      35 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1_1/efficientnetb3_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 217s 513ms/step - accuracy: 0.7523 - auc: 0.8387 - loss: 0.1712 - val_accuracy: 0.6506 - val_auc: 0.8245 - val_loss: 0.1769 - learning_rate: 1.0000e-05
# Epoch 2/10
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 137s 491ms/step - accuracy: 0.8829 - auc: 0.9525 - loss: 0.0727 - val_accuracy: 0.6620 - val_auc: 0.8390 - val_loss: 0.1493 - learning_rate: 1.0000e-05
# Epoch 3/10
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 137s 490ms/step - accuracy: 0.9028 - auc: 0.9667 - loss: 0.0603 - val_accuracy: 0.6797 - val_auc: 0.8693 - val_loss: 0.1373 - learning_rate: 1.0000e-05
# Epoch 4/10
# ...

# %%
# 📈 Plot Training History
def plot_history(h):
    plt.plot(h.history['accuracy'], label='Train Acc')
    plt.plot(h.history['val_accuracy'], label='Val Acc')
    plt.title("Training & Validation Accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_history(history)

# 🧪 Evaluation
loss, acc, auc = model.evaluate(test_ds)
print(f"\nTest Accuracy: {acc:.4f}, AUC: {auc:.4f}")

# 📊 Confusion Matrix and Report with custom threshold
y_true = []
y_pred = []

threshold = 0.3  # lower threshold to improve recall on abnormal class
for images, labels in test_ds:
    probs = model.predict(images).flatten()
    preds = (probs > threshold).astype(int)
    y_pred.extend(preds)
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=["Normal", "Abnormal"],
            yticklabels=["Normal", "Abnormal"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix (Threshold = 0.3)")
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8957 - auc: 0.5536 - loss: 0.0465
#
# Test Accuracy: 0.7590, AUC: 0.9600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# ...

# %%
print(classification_report(y_true, y_pred, target_names=["Normal", "Abnormal"]))

# 💾 Save as .h5 for offline use
model.save("LungAbnormalityDetectorTwoModel.h5")

# 💡 Optional: Export to .tflite for mobile/edge
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("LungAbnormalityDetectorTwoModel.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.89      0.90       380
#     Abnormal       0.90      0.91      0.90       400
#
#     accuracy                           0.90       780
#    macro avg       0.90      0.90      0.90       780
# weighted avg       0.90      0.90      0.90       780
#
# Saved artifact at '/tmp/tmpw_wqwocb'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='keras_tensor_385')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   132805831525008: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132805831525776: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132805964051856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132805964054352: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
