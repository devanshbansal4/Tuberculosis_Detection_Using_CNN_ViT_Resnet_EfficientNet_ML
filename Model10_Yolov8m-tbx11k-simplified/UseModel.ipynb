# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO(r"C:\Users\Devansh\Desktop\ProjectYolo\Model10_Yolov8m-tbx11k-simplified\best.pt")

# %%
# best threshold is 0.1

# Predict on an image
results = model.predict(r"C:\Users\Devansh\Desktop\ProjectYolo\yolo-Datasets\yolo-tbx11k-simplified\images\val\tb0832.png", conf=0.1)

# Show results
results[0].show()
# Out:
# image 1/1 C:\Users\Devansh\Desktop\ProjectYolo\yolo-Datasets\yolo-tbx11k-simplified\images\val\tb0832.png: 512x512 5 tbs, 1250.2ms
# Speed: 5.7ms preprocess, 1250.2ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 512)

# %%
# performance

Confidence Threshold  Recall  Average IoU
0                   0.05   0.735     0.714457
1                   0.10   0.685     0.714737
2                   0.15   0.615     0.709390
3                   0.20   0.510     0.712310
4                   0.25   0.380     0.725979
5                   0.30   0.280     0.734651
6                   0.35   0.230     0.741473
7                   0.40   0.125     0.767799
8                   0.45   0.040     0.773012
9                   0.50   0.015     0.833823
10                  0.55   0.005     0.773525
11                  0.60   0.000     0.000000
12                  0.65   0.000     0.000000
13                  0.70   0.000     0.000000
14                  0.75   0.000     0.000000
15                  0.80   0.000     0.000000
16                  0.85   0.000     0.000000
17                  0.90   0.000     0.000000
