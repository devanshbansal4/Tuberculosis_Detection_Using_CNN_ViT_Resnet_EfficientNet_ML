# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO(r"C:\Users\Devansh\Desktop\ProjectYolo\Model9_Yolov8-new-tbx11k\best_tb_model.pt")

# %%
# Predict on an image
results = model.predict(r"C:\Users\Devansh\Desktop\kechuppieyyyyy.png", conf=0.5)

# Show results
results[0].show()
# Out:
# image 1/1 C:\Users\Devansh\Desktop\kechuppieyyyyy.png: 512x448 (no detections), 655.8ms
# Speed: 10.5ms preprocess, 655.8ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 448)
